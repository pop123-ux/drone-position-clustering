# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/MLCompete/Scantei/dataset/dataset.csv')

# %%
df.head()
# Out:
#       Name                  Timestamp           X           Y
# 0  qdugzqd  Jan 26, 2026, 12:00:03 AM   54.019410   69.212326
# 1  qdugzqd  Jan 26, 2026, 12:00:03 AM  176.670391   66.628831
# 2  qdugzqd  Jan 26, 2026, 12:00:03 AM  185.917840  105.632155
# 3  qdugzqd  Jan 26, 2026, 12:00:03 AM  127.891247   52.613789
# 4  qdugzqd  Jan 26, 2026, 12:00:03 AM   89.019781   36.288286

# %%
r1 = len(df['Name'].unique())

T1 = pd.DataFrame({
    'id': "GLOBAL",
    'subtaskID': 'task1',
    'answer': r1
})

# %%
r2 = len(df[df['Name'] == 'qdugzqd']) * T1

T2 = pd.DataFrame({
    'id': "GLOBAL",
    'subtaskID': 'task2',
    'answer': r2
})
# Out:
# 31250

# %%
len(df)
# Out:
# 31250
